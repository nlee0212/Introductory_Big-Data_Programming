# %%
import matplotlib.pyplot as plt

plt.pie([26.2,30.6,16.2,26.9],labels=['Java','Ruby','C++','Python'],explode=[0,0,0,0.1],
        shadow=True,autopct="%.1f%%",startangle=140,counterclock=False, colors=['lightskyblue','lightcoral','yellowgreen','gold'])
# Out:
# ([<matplotlib.patches.Wedge at 0x20fb1528d88>,
# ...
#  [Text(-0.05359656832580278, 1.0986935004193379, 'Java'),
#   Text(1.0847567595594907, -0.1824904726006093, 'Ruby'),
#   Text(-0.07431633795250304, -1.0974867114973783, 'C++'),
#   Text(-1.186916458713218, -0.17671819384453338, 'Python')],
#  [Text(-0.02923449181407424, 0.5992873638650934, '26.2%'),
#   Text(0.5916855052142675, -0.09954025778215052, '30.6%'),
#   Text(-0.040536184337728924, -0.5986291153622062, '16.2%'),
#   Text(-0.6923679342493771, -0.1030856130759778, '26.9%')])

# %%
import numpy as np
import matplotlib.image as mpimg
img = mpimg.imread("민들레꽃.jpg")
plt.imshow(img)
plt.axis('off')
print(end="")
